# %% [markdown]
# <a href="https://colab.research.google.com/github/aliraza33833/CE889/blob/main/week02/Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### In this lab, you need to create a function, where a vector can be visualised before and after linear transformation.

# %% [markdown]
# 1. Scaling

# %% [markdown]
# 1.1 Let’s have a 2D vector [1, 1]. After the scaling transformation by the factor of 2, it becomes a vector [2, 2]. Draw these two vectors in different colours on the same figure (a figure like the below one). Formula: scaling factor*vector.

# %% [markdown]
# 1.2 Create a function with two input arguments, by which the above figure can be generated when users input a 2D vector and the scaling factor.

# %% [markdown]
# 2. Rotation

# %% [markdown]
# Create a function, by which a vector can be visualised before and after the rotation. Users are allowed to specify two input arguments: a 2D vector and rotation degree.
# Formula: [cos𝜃−sin𝜃sin𝜃cos𝜃]*vector
# After users input the vector [1, 1] and rotation degree 90, the below figure should be generated by the function.
